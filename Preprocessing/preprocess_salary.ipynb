# %%
import pandas as pd

# %%
df3 = pd.read_csv('players.csv')

df6 = pd.read_csv('salary.csv')

# %%
df3
# Out:
#            PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0        Royce O'Neale  1610612762    1626220    2019
# 1     Bojan Bogdanovic  1610612762     202711    2019
# 2          Rudy Gobert  1610612762     203497    2019
# 3     Donovan Mitchell  1610612762    1628378    2019
# 4          Mike Conley  1610612762     201144    2019
# ...                ...         ...        ...     ...
# 7223       Lanny Smith  1610612758     201831    2009
# 7224     Warren Carter  1610612752     201999    2009
# 7225      Bennet Davis  1610612751     201834    2009
# 7226    Brian Hamilton  1610612751     201646    2009
# 7227   Wesley Matthews  1610612762     500032    2009
#
# [7228 rows x 4 columns]

# %%
df6
# Out:
#            PLAYER_NAME POSITION               NAME    SALARY  SEASON  \
# 0        Kevin Garnett       PF     Boston Celtics  24751934    2009
# 1      Stephon Marbury       PG     Boston Celtics  20840625    2009
# 2            Ray Allen       SG     Boston Celtics  18388430    2009
# 3          Paul Pierce       SF     Boston Celtics  18077903    2009
# 4     Kendrick Perkins        C     Boston Celtics   4578880    2009
# ...                ...      ...                ...       ...     ...
# 5951         Ivan Rabb       PF  Memphis Grizzlies   1378242    2019
# 5952       Joakim Noah        C  Memphis Grizzlies   1093858    2019
# 5953      Jevon Carter       PG  Memphis Grizzlies    838464    2019
# 5954     Bruno Caboclo       SF  Memphis Grizzlies    522151    2019
# 5955      Tyler Zeller        C  Memphis Grizzlies     59820    2019
#
#          TEAM_ID
# 0     1610612738
# 1     1610612738
# 2     1610612738
# 3     1610612738
# 4     1610612738
# ...          ...
# ...

# %%
df_sal_player=pd.merge(df6,df3, how="inner", on=["TEAM_ID"])
df_sal_player
# Out:
#          PLAYER_NAME_x POSITION               NAME    SALARY  SEASON_x  \
# 0        Kevin Garnett       PF     Boston Celtics  24751934      2009
# 1        Kevin Garnett       PF     Boston Celtics  24751934      2009
# 2        Kevin Garnett       PF     Boston Celtics  24751934      2009
# 3        Kevin Garnett       PF     Boston Celtics  24751934      2009
# 4        Kevin Garnett       PF     Boston Celtics  24751934      2009
# ...                ...      ...                ...       ...       ...
# 1437415   Tyler Zeller        C  Memphis Grizzlies     59820      2019
# 1437416   Tyler Zeller        C  Memphis Grizzlies     59820      2019
# 1437417   Tyler Zeller        C  Memphis Grizzlies     59820      2019
# 1437418   Tyler Zeller        C  Memphis Grizzlies     59820      2019
# 1437419   Tyler Zeller        C  Memphis Grizzlies     59820      2019
#
#             TEAM_ID   PLAYER_NAME_y  PLAYER_ID  SEASON_y
# 0        1610612738    Jaylen Brown    1627759      2019
# ...

# %%
df_sal_player=pd.merge(df6,df3, how="inner", on=["PLAYER_NAME"])
df_sal_player
# Out:
#                PLAYER_NAME POSITION               NAME    SALARY  SEASON_x  \
# 0            Kevin Garnett       PF     Boston Celtics  24751934      2009
# 1            Kevin Garnett       PF     Boston Celtics  24751934      2009
# 2            Kevin Garnett       PF     Boston Celtics  24751934      2009
# 3            Kevin Garnett       PF     Boston Celtics  24751934      2009
# 4            Kevin Garnett       PF     Boston Celtics  24751934      2009
# ...                    ...      ...                ...       ...       ...
# 40910  Xavier Rathan-Mayes       SG  Memphis Grizzlies    815615      2018
# 40911    Jaren Jackson Jr.       PF  Memphis Grizzlies   5915040      2019
# 40912    Jaren Jackson Jr.       PF  Memphis Grizzlies   5915040      2019
# 40913         Jevon Carter       PG  Memphis Grizzlies    838464      2019
# 40914         Jevon Carter       PG  Memphis Grizzlies    838464      2019
#
#         TEAM_ID_x   TEAM_ID_y  PLAYER_ID  SEASON_y
# ...

# %%
df_sal_player = df_sal_player.drop_duplicates()
df_sal_player
# Out:
#                PLAYER_NAME POSITION               NAME    SALARY  SEASON_x  \
# 0            Kevin Garnett       PF     Boston Celtics  24751934      2009
# 1            Kevin Garnett       PF     Boston Celtics  24751934      2009
# 2            Kevin Garnett       PF     Boston Celtics  24751934      2009
# 3            Kevin Garnett       PF     Boston Celtics  24751934      2009
# 4            Kevin Garnett       PF     Boston Celtics  24751934      2009
# ...                    ...      ...                ...       ...       ...
# 40910  Xavier Rathan-Mayes       SG  Memphis Grizzlies    815615      2018
# 40911    Jaren Jackson Jr.       PF  Memphis Grizzlies   5915040      2019
# 40912    Jaren Jackson Jr.       PF  Memphis Grizzlies   5915040      2019
# 40913         Jevon Carter       PG  Memphis Grizzlies    838464      2019
# 40914         Jevon Carter       PG  Memphis Grizzlies    838464      2019
#
#         TEAM_ID_x   TEAM_ID_y  PLAYER_ID  SEASON_y
# ...

# %%
df_sal_player.to_csv('checksal1.csv', index = False)
